# %%
import copy
import math
from numpy.random import rand
import numpy as np
from numpy.random import randint
import matplotlib.pyplot as plt


def f1(x):
    """
        Function to calculate the Sphere function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    total = np.sum(np.square(x))
    return total

def f4(x):
    """
        Function to calculate the Griewank's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    p1 = 0
    p2 = 1
    for i in range(len(x)):
        p1 += x[i]**2
        p2 *= np.cos(x[i]/(np.sqrt(i+1)))
    
    total = (p1/4000.0) - p2 + 1
    return total
    
    
def f6(x):
    """
        Function to calculate the Rastrigin's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    for i in range(len(x)):
        total += x[i]**2 - (10 * np.cos(2 * np.pi * x[i])) + 10
        
    return total

class Chromosome:
    """
    Class that represents candidate solutions or individuals in the population
    
    Attributes:
    cost_func - fitness function
    n_dims - number of dimensions
    lower_bound and upper_bound - represents bounds for the individual
    chromosome - represents the individual's position
    
    """
    def __init__(self, cost_func, n_dims=10): 
        self.cost_func = cost_func
        self.n_dims = n_dims # = dim
        self.lower_bound = get_bounds(cost_func)[0]
        self.upper_bound = get_bounds(cost_func)[1]
        self.chromosome = self.get_chromosome()

    def get_chromosome(self):
        """
        Individual's position is filled with randomly generated uniformly distributed
        numbers (genes or dimensions) with upper and lower bounds
        """
        chromosome = np.random.uniform(self.lower_bound, self.upper_bound, self.n_dims)
        return chromosome

    def set_chromosome(self, chromosome):
        self.chromosome = chromosome

        
def get_bounds(funcname):
    """
    Function for getting the minimum and maximum bounds depending 
    on the name of the function that will be optimised
    """
    min_bound = 0 # minimum position value
    max_bound = 0 # maximum position value
    
    if funcname == 'f1':
        min_bound = -100
        max_bound = 100
        
    elif funcname == "f4":
        min_bound = -600
        max_bound = 600
            
    elif funcname == "f6":
        min_bound = -5.12
        max_bound = 5.12
        
    return (min_bound, max_bound)

def get_func(funcname, chromosome):
    """
        Function to get the right function and run it for a given individual.
        
        Attributes:
            funcname - name of the function that will be optimized
            chromosome - position of the individual
    """
    val = 0
    
    # depending on the function inputted, run the function on the position of the given particle
    if funcname == 'f1':
        val = f1(chromosome.chromosome)
        
    elif funcname == 'f4':
        val = f4(chromosome.chromosome)
            
    elif funcname == 'f6':
        val = f6(chromosome.chromosome)

    return val


def tournament_selection(population, f, k=5):
    """
    Several tournaments are run and the individuals with the best fitness are selected for crossover
    """
    pop = len(population) 
    selection_ix = randint(pop) # first random selection of parent chromosomes
    
    output = []
    for p in population:
        output.append(get_func(f, p))    
    for ix in randint(0, pop, k-1):
        # check for individual with best fitness
        if output[ix] < output[selection_ix]:
            selection_ix = ix
    
    return population[selection_ix]



def crossover(parent1, parent2, cost_function):
    """
    One or single point crossover of two parents to create two children
    """
#     child1 = Chromosome(cost_function)
#     child2 = Chromosome(cost_function)

    child1 = copy.deepcopy(parent1)
    child2 = copy.deepcopy(parent2)

    # the chromosome is cut or split at a random point, and the leftover chromosomes  
    # are swapped to produce two new offspring 
    split_point = int(np.random.randint(0, parent1.chromosome.shape)) 
    child1_chromosome = np.concatenate((parent1.chromosome[0: split_point], parent2.chromosome[split_point:]))
    child1.set_chromosome(child1_chromosome)

    child2_chromosome = np.concatenate((parent2.chromosome[0: split_point], parent1.chromosome[split_point:]))
    child2.set_chromosome(child2_chromosome)

    return child1, child2


def mutate(solution, mu, sigma):
    """
    solution: child chromosome 
    mu: mutation rate. % of gene to be modified
    sigma: step size of mutation
    
    """
        
    sol = copy.deepcopy(solution)
    flag = np.random.rand(*solution.chromosome.shape) <= mu
    ind = np.argwhere(flag)
    sol.chromosome[ind] = sigma * np.random.randn(*ind.shape)
    return sol


def best_solution(population, f):
    best_cost = math.inf
    for sol in population:
        if get_func(f, sol) < best_cost:
            best_cost = get_func(f, sol)
    return best_cost


def GA(num_iter, num_generations, Npopulation, cost_function, mu, sigma): # add param
    average_cost = 0
    for i in range(num_iter):
        generations = []
        best_solution_per_generation = []

        init_population = []
        for n in range(Npopulation):
            init_population.append(Chromosome(cost_function))

        generations.append(init_population)

        for j in range(num_generations):
            current_population = generations[-1]
            new_population = []
            for k in range(Npopulation // 2):
                p1 = tournament_selection(current_population,cost_function)
                p2 = tournament_selection(current_population,cost_function)
                child1, child2 = crossover(p1, p2, cost_function)
                child1 = mutate(child1, mu, sigma)
                child2 = mutate(child2, mu, sigma)
                new_population.append(child1)
                new_population.append(child2)
            generations.append(new_population)

            best = best_solution(current_population,cost_function)
            best_solution_per_generation.append(best)
        print(f'best solution in iteration {i}: {best}')
        average_cost += best

    print('average cost:', average_cost / num_iter)
    plt.plot(best_solution_per_generation)
    plt.title(f'{cost_function} function over generation')
    plt.xlabel('generations')
    plt.ylabel('best solution')
    plt.show()
    
GA(100, 20, 20, 'f1', 0.2, 0.02)
# Out:
# best solution in iteration 0: 0.0004171467266375967
# best solution in iteration 1: 0.00017233116055078956
# best solution in iteration 2: 0.0002396746871087289
# best solution in iteration 3: 0.00026813316769193845
# best solution in iteration 4: 0.00031451789144035653
# best solution in iteration 5: 0.00020019743899367656
# best solution in iteration 6: 0.0003421247403740851
# best solution in iteration 7: 0.00031901489967502345
# best solution in iteration 8: 0.00018882091933370776
# best solution in iteration 9: 0.00017031231245102997
# best solution in iteration 10: 0.00036262970122245044
# best solution in iteration 11: 0.00016372420328782336
# best solution in iteration 12: 0.00020410024570383337
# best solution in iteration 13: 0.00027688390451452514
# best solution in iteration 14: 0.00042546038290718974
# best solution in iteration 15: 0.00047105987673629605
# best solution in iteration 16: 0.00024963156324149803
# best solution in iteration 17: 0.000197861679245176
# best solution in iteration 18: 0.00040582214936176907
# best solution in iteration 19: 0.00028801487384288787
# best solution in iteration 20: 8.55187967792374e-05
# best solution in iteration 21: 0.0003002939726956346
# best solution in iteration 22: 0.00026343863945060104
# best solution in iteration 23: 0.0002789563619250764
# best solution in iteration 24: 0.0003505612796130238
# best solution in iteration 25: 0.00023574533059826593
# best solution in iteration 26: 0.0002522783940682625
# best solution in iteration 27: 8.197502530343594e-05
# best solution in iteration 28: 0.0002127057322994791
# best solution in iteration 29: 0.0003422901070444844
# best solution in iteration 30: 0.00012601277374430536
# best solution in iteration 31: 0.00024212867559444718
# best solution in iteration 32: 0.00028547212853619107
# best solution in iteration 33: 0.00016294291200523006
# best solution in iteration 34: 0.00025285708530053594
# best solution in iteration 35: 0.0003482088927726885
# best solution in iteration 36: 0.0001235988423926329
# best solution in iteration 37: 0.00023821367657928286
# best solution in iteration 38: 0.00022910156939998097
# best solution in iteration 39: 0.00033686580757423144
# best solution in iteration 40: 0.0003092527815873348
# best solution in iteration 89: 0.0009372863817728172
# best solution in iteration 90: 0.0009190584914778865
# best solution in iteration 91: 0.0005237645252550438
# best solution in iteration 92: 0.0004594282181134002
# best solution in iteration 93: 0.0007678392146275304
# best solution in iteration 94: 0.0008066995901014895
# best solution in iteration 95: 0.0011198262654815716
# best solution in iteration 96: 0.0013649091030686344
# best solution in iteration 97: 0.0011973202597505006
# best solution in iteration 98: 0.00026434542046804843
# best solution in iteration 99: 0.0005747551572361509
# average cost: 0.0007398511018235632

# %%
GA(100, 100, 200, 'f1', 0.2, 0.02)
# Out:
# best solution in iteration 0: 2.3522987442216833e-05
# best solution in iteration 1: 2.133800185625863e-05
# best solution in iteration 2: 5.550262360479961e-05
# best solution in iteration 3: 4.183567572648229e-05
# best solution in iteration 4: 5.2555570152278004e-05
# best solution in iteration 5: 4.737546177486933e-05
# best solution in iteration 6: 9.673164399270558e-05
# best solution in iteration 7: 7.267205167752783e-05
# best solution in iteration 8: 6.0872712379000336e-05
# best solution in iteration 9: 5.918621357400672e-05
# best solution in iteration 10: 5.876461602441302e-05
# best solution in iteration 11: 7.024589615065159e-05
# best solution in iteration 12: 4.084544373909672e-05
# best solution in iteration 13: 2.9399814360575306e-05
# best solution in iteration 14: 4.539747298122097e-05
# best solution in iteration 15: 4.720547672180908e-05
# best solution in iteration 16: 8.052551952410892e-05
# best solution in iteration 17: 2.958893214211382e-05
# best solution in iteration 18: 5.4357895341744546e-05
# best solution in iteration 19: 5.093235051080827e-05
# best solution in iteration 20: 5.3098812960367867e-05
# best solution in iteration 21: 6.366028865829692e-05
# best solution in iteration 22: 7.461634756365898e-05
# best solution in iteration 23: 3.701359763546526e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 GA(100, 100, 200, 'f1', 0.2, 0.02)
#
# Input In [49], in GA(num_iter, num_generations, Npopulation, cost_function, mu, sigma)
#     208 child1, child2 = crossover(p1, p2, cost_function)
#     209 child1 = mutate(child1, mu, sigma)
# --> 210 child2 = mutate(child2, mu, sigma)
#     211 new_population.append(child1)
#     212 new_population.append(child2)
#
# Input In [49], in mutate(solution, mu, sigma)
#     176 flag = np.random.rand(*solution.chromosome.shape) <= mu
#     177 ind = np.argwhere(flag)
# --> 178 sol.chromosome[ind] = sigma * np.random.randn(*ind.shape)
#     179 return sol
#
# KeyboardInterrupt:

# %%
GA(100, 30, 50, 'f6', 0.02, 0.1)
# Out:
# best solution in iteration 0: 0.3894855506330295
# best solution in iteration 1: 0.47041538952096396
# best solution in iteration 2: 0.5062873416579752
# best solution in iteration 3: 0.3301378308355787
# best solution in iteration 4: 0.2606073710243795
# best solution in iteration 5: 0.1225627793601074
# best solution in iteration 6: 0.8186678607655811
# best solution in iteration 7: 0.2390435879058117
# best solution in iteration 8: 0.9607186751651628
# best solution in iteration 9: 0.2658327138811849
# best solution in iteration 10: 0.5671260698031784
# best solution in iteration 11: 0.3418269652375656
# best solution in iteration 12: 0.952172624684783
# best solution in iteration 13: 0.4813764308552404
# best solution in iteration 14: 0.5923756743176085
# best solution in iteration 15: 0.28049848093635177
# best solution in iteration 16: 0.34144438186298487
# best solution in iteration 17: 0.23900880379558664
# best solution in iteration 18: 0.5981261180738286
# best solution in iteration 19: 0.6719643419241521
# best solution in iteration 20: 0.27061631351517157
# best solution in iteration 21: 0.5208106824082375

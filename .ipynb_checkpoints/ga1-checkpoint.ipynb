# %%
import copy
import math
from numpy.random import rand
import numpy as np
from numpy.random import randint
import matplotlib.pyplot as plt


def f1(x):
    """
        Function to calculate the Sphere function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    total = np.sum(np.square(x))
    return total

def f4(x):
    """
        Function to calculate the Griewank's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    p1 = 0
    p2 = 1
    for i in range(len(x)):
        p1 += x[i]**2
        p2 *= np.cos(x[i]/(np.sqrt(i+1)))
    
    total = (p1/4000.0) - p2 + 1
    return total
    
    
def f6(x):
    """
        Function to calculate the Rastrigin's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    for i in range(len(x)):
        total += x[i]**2 - (10 * np.cos(2 * np.pi * x[i])) + 10
        
    return total

class Chromosome:
    """
    Class that represents candidate solutions or individuals in the population
    
    Attributes:
    cost_func - fitness function
    n_dims - number of dimensions
    lower_bound and upper_bound - represents bounds for the individual
    chromosome - represents the individual's position
    
    """
    def __init__(self, cost_func, n_dims=10): 
        self.cost_func = cost_func
        self.n_dims = n_dims # = dim
        self.lower_bound = get_bounds(cost_func)[0]
        self.upper_bound = get_bounds(cost_func)[1]
        self.chromosome = self.get_chromosome()

    def get_chromosome(self):
        """
        Individual's position is filled with randomly generated uniformly distributed
        numbers (genes or dimensions) with upper and lower bounds
        """
        chromosome = np.random.uniform(self.lower_bound, self.upper_bound, self.n_dims)
        return chromosome

    def set_chromosome(self, chromosome):
        self.chromosome = chromosome

        
def get_bounds(funcname):
    """
    Function for getting the minimum and maximum bounds depending 
    on the name of the function that will be optimised
    """
    min_bound = 0 # minimum position value
    max_bound = 0 # maximum position value
    
    if funcname == 'f1':
        min_bound = -100
        max_bound = 100
        
    elif funcname == "f4":
        min_bound = -600
        max_bound = 600
            
    elif funcname == "f6":
        min_bound = -5.12
        max_bound = 5.12
        
    return (min_bound, max_bound)

def get_func(funcname, chromosome):
    """
        Function to get the right function and run it for a given individual.
        
        Attributes:
            funcname - name of the function that will be optimized
            chromosome - position of the individual
    """
    val = 0
    
    # depending on the function inputted, run the function on the position of the given particle
    if funcname == 'f1':
        val = f1(chromosome.chromosome)
        
    elif funcname == 'f4':
        val = f4(chromosome.chromosome)
            
    elif funcname == 'f6':
        val = f6(chromosome.chromosome)

    return val


def tournament_selection(population, f, k=5):
    """
    Several tournaments are run and the individuals with the best fitness are selected for crossover
    """
    pop = len(population) 
    selection_ix = randint(pop) # first random selection of parent chromosomes
    
    output = []
    for p in population:
        output.append(get_func(f, p))    
    for ix in randint(0, pop, k-1):
        # check for individual with best fitness
        if output[ix] < output[selection_ix]:
            selection_ix = ix
    
    return population[selection_ix]



def crossover(parent1, parent2, cost_function, cross_rate):
    """
    One or single point crossover of two parents to create two children
    """
    
    child1 = copy.deepcopy(parent1) # children are copies of parents by default
    child2 = copy.deepcopy(parent2)

#     child1 = Chromosome(cost_function)
#     child2 = Chromosome(cost_function)

    # the chromosome is cut or split at a random point, and the leftover chromosomes  
    # are swapped to produce two new offspring 
    if np.random.random() < cross_rate:   # crossover rate that determines whether crossover is performed or not

        split_point = int(np.random.randint(0, parent1.chromosome.shape)) 
        child1_chromosome = np.concatenate((parent1.chromosome[0: split_point], parent2.chromosome[split_point:]))
        child1.set_chromosome(child1_chromosome)

        child2_chromosome = np.concatenate((parent2.chromosome[0: split_point], parent1.chromosome[split_point:]))
        child2.set_chromosome(child2_chromosome)

    return child1, child2


def mutate(solution, mu):
    """
    solution: child chromosome 
    mu: mutation rate. % of gene to be modified
    sigma: step size of mutation
    
    """
        
    sol = copy.deepcopy(solution)
    # array of True and False, indicating the mutation position
    flag = np.random.rand(*solution.chromosome.shape) <= mu  #generating random numbers and comparing them to the mutation rate
    ind = np.argwhere(flag) # argwhere returns the position where the expression above is true
#     sol.chromosome[ind] += 1 * np.random.randn(*ind.shape) # replacing those positions with new mutated genes generated
    sol.chromosome[ind] = np.random.uniform(solution.lower_bound, solution.upper_bound)
    return sol



def best_solution(population, f):
    best_cost = math.inf
    for sol in population:
        if get_func(f, sol) < best_cost:
            best_cost = get_func(f, sol)
    return best_cost


def GA(num_iter, num_generations, Npopulation, cost_function, mu, cross_rate): # add param
    average_cost = 0
    for i in range(num_iter):
        generations = []
        best_solution_per_generation = []

        init_population = []
        for n in range(Npopulation):
            init_population.append(Chromosome(cost_function))

        generations.append(init_population)

        for j in range(num_generations):
            current_population = generations[-1]
            new_population = []
            for k in range(Npopulation // 2):
                p1 = tournament_selection(current_population,cost_function)
                p2 = tournament_selection(current_population,cost_function)
                child1, child2 = crossover(p1, p2, cost_function, cross_rate)
                child1 = mutate(child1, mu)
                child2 = mutate(child2, mu)
                new_population.append(child1)
                new_population.append(child2)
            generations.append(new_population)

            best = best_solution(current_population,cost_function)
            best_solution_per_generation.append(best)
        print(f'best solution in iteration {i}: {best}')
        average_cost += best

    print('average cost:', average_cost / num_iter)
    plt.plot(best_solution_per_generation)
    plt.title(f'{cost_function} function over generation')
    plt.xlabel('generations')
    plt.ylabel('best solution')
    plt.show()

# %%
# GA(50, 400, 100, 'f1', 0.01)
#GA(50, 500, 100, 'f1', 0.01) # GOOD CONVERGENCE BUT TOO LONG
# GA(50, 1000, 20, 'f1', 0.04) # 0.36
GA(50, 1000, 30, 'f1', 0.06) # 0.09
# Out:
# best solution in iteration 0: 0.03800368834745643
# best solution in iteration 1: 0.04543257191636735
# best solution in iteration 2: 0.026921836173531097
# best solution in iteration 3: 0.06516495266047953
# best solution in iteration 4: 0.0920987332245614
# best solution in iteration 5: 0.23859575800184932
# best solution in iteration 6: 0.039042228047683245
# best solution in iteration 7: 0.05399356558623085
# best solution in iteration 8: 0.19637192956552246
# best solution in iteration 9: 0.057918350964450575
# best solution in iteration 10: 0.14914346523250607
# best solution in iteration 11: 0.06055431429864618
# best solution in iteration 12: 0.13137590270149946
# best solution in iteration 13: 0.09073479538625308
# best solution in iteration 14: 0.1070068939156641
# best solution in iteration 15: 0.015344715931622333
# best solution in iteration 16: 0.09329223030715633
# best solution in iteration 17: 0.030429629073592875
# best solution in iteration 18: 0.08722378580197103
# best solution in iteration 19: 0.08136691864162107
# best solution in iteration 20: 0.18113591895817124
# best solution in iteration 21: 0.11903678376200515
# best solution in iteration 22: 0.1213515682710365
# best solution in iteration 23: 0.040566314723424965
# best solution in iteration 24: 0.036460074649228465
# best solution in iteration 25: 0.08398283404380946
# best solution in iteration 26: 0.03123813460556342
# best solution in iteration 27: 0.06995702288862801
# best solution in iteration 28: 0.06800374457406326
# best solution in iteration 29: 0.050625662656809
# best solution in iteration 30: 0.03291518545426193
# best solution in iteration 31: 0.11929427721331079
# best solution in iteration 32: 0.04058966376893043
# best solution in iteration 33: 0.1674650151354066
# best solution in iteration 34: 0.14307009231030995
# best solution in iteration 35: 0.11554388358370377
# best solution in iteration 36: 0.10463598322426224
# best solution in iteration 37: 0.09722889052725547
# best solution in iteration 38: 0.061866560152120546
# best solution in iteration 39: 0.07425277417439234
# best solution in iteration 40: 0.05087823487219428
# best solution in iteration 41: 0.044453722526351144
# best solution in iteration 42: 0.07772284876605824
# best solution in iteration 43: 0.11767475592432401
# best solution in iteration 44: 0.07669470116120751
# best solution in iteration 45: 0.15131159375521222
# best solution in iteration 46: 0.14024068522974695
# best solution in iteration 47: 0.20720958687771626
# best solution in iteration 48: 0.2000865308071808
# best solution in iteration 49: 0.10545399411278805
# average cost: 0.09261926608976274

# %%
GA(50, 100, 30, 'f1', 0.02, 0.25)
# Out:
# best solution in iteration 0: 224.74177539914155
# best solution in iteration 1: 91.23244131686795
# best solution in iteration 2: 23.725794796907966
# best solution in iteration 3: 51.416323127126645
# best solution in iteration 4: 58.33381178114243
# best solution in iteration 5: 71.59801813403396
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [282], in <cell line: 1>()
# ----> 1 GA(50, 100, 30, 'f1', 0.02, 0.25)
#
# Input In [211], in GA(num_iter, num_generations, Npopulation, cost_function, mu, cross_rate)
#     214 child1, child2 = crossover(p1, p2, cost_function, cross_rate)
#     215 child1 = mutate(child1, mu)
# --> 216 child2 = mutate(child2, mu)
#     217 new_population.append(child1)
#     218 new_population.append(child2)
#
# Input In [211], in mutate(solution, mu)
#     178     sol = copy.deepcopy(solution)
#     179     # array of True and False, indicating the mutation position
# --> 180     flag = np.random.rand(*solution.chromosome.shape) <= mu  #generating random numbers and comparing them to the mutation rate
#     181     ind = np.argwhere(flag) # argwhere returns the position where the expression above is true
#     182 #     sol.chromosome[ind] += 1 * np.random.randn(*ind.shape) # replacing those positions with new mutated genes generated
#
# KeyboardInterrupt:

# %%
GA(20, 100, 50, 'f4', 0.15, 0.02)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [141], in <cell line: 1>()
# ----> 1 GA(20, 100, 200, 'f4', 0.15)
#
# Input In [140], in GA(num_iter, num_generations, Npopulation, cost_function, mu)
#     208 new_population = []
#     209 for k in range(Npopulation // 2):
# --> 210     p1 = tournament_selection(current_population,cost_function)
#     211     p2 = tournament_selection(current_population,cost_function)
#     212     child1, child2 = crossover(p1, p2, cost_function)
#
# Input In [140], in tournament_selection(population, f, k)
#     133 output = []
#     134 for p in population:
# --> 135     output.append(get_func(f, p))
#     136 for ix in randint(0, pop, k-1):
#     137     # check for individual with best fitness
#     138     if output[ix] < output[selection_ix]:
#
# Input In [140], in get_func(funcname, chromosome)
#     115     val = f1(chromosome.chromosome)
#     117 elif funcname == 'f4':
# --> 118     val = f4(chromosome.chromosome)
#     120 elif funcname == 'f6':
#     121     val = f6(chromosome.chromosome)
#
# Input In [140], in f4(x)
#      30 for i in range(len(x)):
#      31     p1 += x[i]**2
# ---> 32     p2 *= np.cos(x[i]/(np.sqrt(i+1)))
#      34 total = (p1/4000.0) - p2 + 1
#      35 return total
#
# KeyboardInterrupt:

# %%
GA(100, 100, 100, 'f6', 0.03)
# Out:
# best solution in iteration 0: 0.7704245161961989
# best solution in iteration 1: 1.0106967319968412
# best solution in iteration 2: 2.7013755279941254
# best solution in iteration 3: 3.6214852361745695
# best solution in iteration 4: 0.6297077241510891
# best solution in iteration 5: 2.052101090095322
# best solution in iteration 6: 2.0936338719716296
# best solution in iteration 7: 0.8822903583425088
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [202], in <cell line: 1>()
# ----> 1 GA(100, 100, 100, 'f6', 0.03)
#
# Input In [142], in GA(num_iter, num_generations, Npopulation, cost_function, mu)
#     209 for k in range(Npopulation // 2):
#     210     p1 = tournament_selection(current_population,cost_function)
# --> 211     p2 = tournament_selection(current_population,cost_function)
#     212     child1, child2 = crossover(p1, p2, cost_function)
#     213     child1 = mutate(child1, mu)
#
# Input In [142], in tournament_selection(population, f, k)
#     134 for p in population:
#     135     output.append(get_func(f, p))
# --> 136 for ix in randint(0, pop, k-1):
#     137     # check for individual with best fitness
#     138     if output[ix] < output[selection_ix]:
#     139         selection_ix = ix
#
# KeyboardInterrupt:

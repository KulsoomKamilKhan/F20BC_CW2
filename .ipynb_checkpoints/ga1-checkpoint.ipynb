# %%
import copy
import math

import numpy as np
from numpy.random import randint
import matplotlib.pyplot as plt


def f1(x):
    """
        Function to calculate the Sphere function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    total = np.sum(np.square(x))
    return total

def f4(x):
    """
        Function to calculate the Griewank's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    p1 = 0
    p2 = 1
    for i in range(len(x)):
        p1 += x[i]**2
        p2 *= np.cos(x[i]/(np.sqrt(i+1)))
    
    total = (p1/4000.0) - p2 + 1
    return total
    
    
def f6(x):
    """
        Function to calculate the Rastrigin's function.
        
        Attributes:
            x - candidate solution
    """
    total = 0
    for i in range(len(x)):
        total += x[i]**2 - (10 * np.cos(2 * np.pi * x[i])) + 10
        
    return total

class Chromosome:
    def __init__(self, cost_func, num_genes=10): #num_genes -> dims
        self.cost_func = cost_func
        self.num_genes = num_genes # = dim
        self.lower_bound = get_bounds(cost_func)[0]
        self.upper_bound = get_bounds(cost_func)[1]
        self.chromosome = self.get_chromosome()

    def get_chromosome(self):
        chromosome = np.random.uniform(self.lower_bound, self.upper_bound, self.num_genes)
        return chromosome

    def set_chromosome(self, chromosome):
        self.chromosome = chromosome

def get_bounds(funcname):
    min_bound = 0 # minimum position value
    max_bound = 0 # maximum position value
    
    if funcname == 'f1':
        min_bound = -100
        max_bound = 100
        
    elif funcname == "f4":
        min_bound = -600
        max_bound = 600
            
    elif funcname == "f6":
        min_bound = -5.12
        max_bound = 5.12
        
    return (min_bound, max_bound)

def get_func(funcname, chromosome):
    """
        Function to get the right function and run it for a given particle.
        
        Attributes:
            funcname - name of the function that will be optimized
            particle - particle to run the function for
    """
    val = 0
    
    # depending on the function inputted, run the function on the position of the given particle
    if funcname == 'f1':
        val = f1(chromosome.chromosome)
        
    elif funcname == 'f4':
        val = f4(chromosome.chromosome)
            
    elif funcname == 'f6':
        val = f6(chromosome.chromosome)

    return val


def tournament_selection(population, f, k=5):
    pop = len(population)
    selection_ix = randint(pop)
    
    output = []
    for p in population:
        output.append(get_func(f, p))
#     print(pop)
#     print(k-1)
#     print(k)
    r =  randint(0, pop, k-1)   
    for ix in r:
        if output[ix] < output[selection_ix]:
            selection_ix = ix
    
    return population[selection_ix]



def crossover(parent1, parent2, cost_function):
    child1 = Chromosome(cost_function)
    child2 = Chromosome(cost_function)

    split_point = int(np.random.randint(0, parent1.chromosome.shape))
    child1_chromosome = np.concatenate((parent1.chromosome[0: split_point], parent2.chromosome[split_point:]))
    child1.set_chromosome(child1_chromosome)

    child2_chromosome = np.concatenate((parent2.chromosome[0: split_point], parent1.chromosome[split_point:]))
    child2.set_chromosome(child2_chromosome)

    return child1, child2


def mutate(solution, mu):
    sol = copy.deepcopy(solution)
    flag = np.random.rand(*solution.chromosome.shape) <= mu
    ind = np.argwhere(flag)
    sol.chromosome[ind] = np.random.uniform(solution.lower_bound, solution.upper_bound)
    return sol


def best_solution(population, f):
    best_cost = math.inf
    for sol in population:
        if get_func(f, sol) < best_cost:
            best_cost = get_func(f, sol)
    return best_cost


# # some parameters
# num_iter = 30  # number of times that we are going to run the algorithm
# num_generations = 30  # number of generations that we are going to produce in each iteration
# Npopulation = 50  # Number of population
# cost_function = 
# # + mu, k

def GA(num_iter, num_generations, Npopulation, cost_function, mu): # add param
    average_cost = 0
    for i in range(num_iter):
        generations = []
        best_solution_per_generation = []

        init_population = []
        for n in range(Npopulation):
            init_population.append(Chromosome(cost_function))

        generations.append(init_population)

        for j in range(num_generations):
            current_population = generations[-1]
            new_population = []
            for k in range(Npopulation // 2):
                p1 = tournament_selection(current_population,cost_function)
                p2 = tournament_selection(current_population,cost_function)
                child1, child2 = crossover(p1, p2, cost_function)
                child1 = mutate(child1, mu)
                child2 = mutate(child2, mu)
                new_population.append(child1)
                new_population.append(child2)
            generations.append(new_population)

            best = best_solution(current_population,cost_function)
            best_solution_per_generation.append(best)
        print(f'best solution in iteration {i}: {best}')
        average_cost += best

    print('average cost:', average_cost / num_iter)
    plt.plot(best_solution_per_generation)
    plt.title(f'{cost_function} function over generation')
    plt.xlabel('generations')
    plt.ylabel('best solution')
    plt.show()
    
GA(100, 100, 300, 'f1', 0.02)
# Out:
# best solution in iteration 0: 0.23004655471368965
# best solution in iteration 1: 1.4283829102257009
# best solution in iteration 2: 1.00170935862055
# best solution in iteration 3: 1.0604318437117857
# best solution in iteration 4: 0.5786082003325881
# best solution in iteration 5: 1.0766383924771272
# best solution in iteration 6: 0.5751218774462451
# best solution in iteration 7: 1.3516789812381245
# best solution in iteration 8: 0.5093258225645622
# best solution in iteration 9: 2.4273603713403613
# best solution in iteration 10: 1.4158684372472383
# best solution in iteration 11: 0.7269286907855045
# best solution in iteration 12: 0.7805264451816313
# best solution in iteration 13: 1.4699225471774535
# best solution in iteration 14: 1.2990257874479527
# best solution in iteration 15: 1.0410819742866204
# best solution in iteration 16: 2.130164076412602
# best solution in iteration 17: 0.15031122826435903
# best solution in iteration 18: 1.3275108188038796
# best solution in iteration 19: 1.145802119291481
# best solution in iteration 20: 0.9343914897016047
# best solution in iteration 21: 0.887552803767917
# best solution in iteration 22: 0.5714067612433525
# best solution in iteration 23: 0.7702203760680643
# best solution in iteration 24: 1.6210869147970077
# best solution in iteration 25: 0.5395357412274614
# best solution in iteration 26: 0.3479917489996113
# best solution in iteration 27: 3.323470838443481
# best solution in iteration 28: 1.2871588961809477
# best solution in iteration 29: 0.27211079490749174
# best solution in iteration 30: 2.219773449425089
# best solution in iteration 31: 0.6186469861176365
# best solution in iteration 32: 0.6160604453539906
# best solution in iteration 33: 1.000808883082875
# best solution in iteration 34: 2.227512681100475
# best solution in iteration 35: 0.40876439536227355
# best solution in iteration 36: 0.5107972279966547
# best solution in iteration 37: 1.5962107419474474
# best solution in iteration 38: 0.3904560551669364
# best solution in iteration 39: 1.1140200388020063
# best solution in iteration 40: 0.7187793722518788
# best solution in iteration 41: 0.8438174475605806
# best solution in iteration 42: 2.1097434205745436
# best solution in iteration 43: 0.9018607261485984
# best solution in iteration 44: 0.8722606721501506
# best solution in iteration 45: 0.8707916723442158
# best solution in iteration 46: 0.7853951625512925
# best solution in iteration 47: 0.9856981715664209
# best solution in iteration 48: 0.7279846330680944
# best solution in iteration 49: 2.641114762830914
# best solution in iteration 50: 3.327452084116069
# best solution in iteration 51: 0.9175624122323989
# best solution in iteration 52: 1.1930519406286113
# best solution in iteration 53: 2.40426420179252
# best solution in iteration 54: 0.9767992477622316
# best solution in iteration 55: 1.1337772666043318
# best solution in iteration 56: 1.2948796645860299
# best solution in iteration 57: 1.3284966474962747
# best solution in iteration 58: 0.4730653531059256
# best solution in iteration 59: 0.703891587393717
# best solution in iteration 60: 0.8188026004351799
# best solution in iteration 61: 1.7274286436694555
# best solution in iteration 62: 1.2432205962201723
# best solution in iteration 63: 1.540795695031699
# best solution in iteration 64: 2.1493665030107745
# best solution in iteration 65: 0.7921480432801273
# best solution in iteration 66: 0.967498741880602
# best solution in iteration 67: 0.5025589210496032
# best solution in iteration 68: 0.7891296274210238
# best solution in iteration 69: 0.8863860295890499
# best solution in iteration 70: 1.152181140935784
# best solution in iteration 71: 1.9770340321948234
# best solution in iteration 72: 0.35717912851610395
# best solution in iteration 73: 0.46744973826303543
# best solution in iteration 74: 6.116957185573079
# best solution in iteration 75: 0.9214273700394023
# best solution in iteration 76: 0.2991205337244528
# best solution in iteration 77: 0.9499870601826471
# best solution in iteration 78: 0.2573748009124696
# best solution in iteration 79: 0.9562601247396245
# best solution in iteration 80: 0.32845956147388977
# best solution in iteration 81: 0.5756892817453446
# best solution in iteration 82: 0.9876300252392096
# best solution in iteration 83: 1.3177231899888282
# best solution in iteration 84: 0.3699040835090517
# best solution in iteration 85: 0.6620316411350344
# best solution in iteration 86: 1.8245989261145212
# best solution in iteration 87: 1.38064833209968
# best solution in iteration 88: 0.8400217332930964
# best solution in iteration 89: 0.9616378425313671
# best solution in iteration 90: 0.7179341189597193
# best solution in iteration 91: 1.183548383628932
# best solution in iteration 92: 0.4523839385175672
# best solution in iteration 93: 0.6498389532731192
# best solution in iteration 94: 1.3736232087023952
# best solution in iteration 95: 0.22367476279467577
# best solution in iteration 96: 0.7675943105900729
# best solution in iteration 97: 1.0300578404290976
# best solution in iteration 98: 0.6489329451516116
# best solution in iteration 99: 0.5628021257762208
# average cost: 1.0992615187564911
